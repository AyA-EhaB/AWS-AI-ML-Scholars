# %% [markdown]
# <a href="https://colab.research.google.com/github/AyA-EhaB/AWS-AI-ML-Scholars/blob/main/AWS_Scholars_EX4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### predict whether a customer will make a purchase based on two features:
#
# * Website visit duration
# * Number of pages visited

# %%
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# Generating synthetic data
np.random.seed(0)
data_size = 200
features = np.random.rand(data_size, 2)  # Two features: visit duration and pages visited
labels = (features[:, 0] + features[:, 1] > 1).astype(int)  # Purchase (1) or not (0)

# Convert to DataFrame for easier manipulation
df = pd.DataFrame(features, columns=['VisitDuration', 'PagesVisited'])
df['Purchase'] = labels



#labels = (features[:, 0] + features[:, 1] > 1).astype(int)
''' this line of code is creating
a binary label array based on the sum of two
features. If the sum of "Visit Duration" and
"Pages Visited" is greater than 1,
it assigns a label of 1 (indicating a purchase);
otherwise, it assigns a label of 0 (indicating no purchase).''';

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['VisitDuration', 'PagesVisited']], df['Purchase'], test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
    Dense(10, activation = 'relu',input_shape = (2,)),
    Dense(1,activation='sigmoid')
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=10,batch_size=10)
# Out:
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5413 - loss: 0.7161
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4630 - loss: 0.7113
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5177 - loss: 0.7025
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4399 - loss: 0.6994
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5743 - loss: 0.6919
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7094 - loss: 0.6862
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7013 - loss: 0.6778
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6791 - loss: 0.6739
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7201 - loss: 0.6651
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7367 - loss: 0.6613

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7771 - loss: 0.6497
# Test Accuracy: 0.7749999761581421

# %%
#Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Train the model and save the history
history = model.fit(X_train, y_train, epochs=10, batch_size=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6972 - loss: 0.6654 - val_accuracy: 0.7812 - val_loss: 0.6405
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7430 - loss: 0.6529 - val_accuracy: 0.7812 - val_loss: 0.6351
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7679 - loss: 0.6460 - val_accuracy: 0.8125 - val_loss: 0.6298
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7626 - loss: 0.6419 - val_accuracy: 0.8125 - val_loss: 0.6247
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7781 - loss: 0.6485 - val_accuracy: 0.8125 - val_loss: 0.6199
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7691 - loss: 0.6456 - val_accuracy: 0.8125 - val_loss: 0.6148
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8434 - loss: 0.6317 - val_accuracy: 0.8125 - val_loss: 0.6094
# Epoch 8/10
# ...

# %%
# Plotting training and validation loss and accuracy
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# Generate a grid over the feature space
x_min, x_max = df['VisitDuration'].min() - 0.1, df['VisitDuration'].max() + 0.1
y_min, y_max = df['PagesVisited'].min() - 0.1, df['PagesVisited'].max() + 0.1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))

# Predict over the grid
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the contour and training examples
plt.contourf(xx, yy, Z, alpha=0.8)
plt.scatter(df['VisitDuration'], df['PagesVisited'], c=df['Purchase'], edgecolor='k')
plt.xlabel('Visit Duration')
plt.ylabel('Pages Visited')
plt.title('Decision Boundary of Neural Network')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %% [markdown]
# * x_min and x_max: These variables define the minimum and maximum values for the x-axis (Visit Duration). The - 0.1 and + 0.1 are added to create a small buffer around the minimum and maximum values, ensuring that the grid covers the entire range of data.

# %% [markdown]
# * np.linspace(...): This function generates 100 evenly spaced values between x_min and x_max for the x-axis, and between y_min and y_max for the y-axis.
# * np.meshgrid(...): This function creates a rectangular grid out of the two 1D arrays generated by np.linspace. The result is two 2D arrays (xx and yy), where each point in the grid corresponds to a combination of Visit Duration and Pages Visited.

# %% [markdown]
# * np.c_[xx.ravel(), yy.ravel()]: This combines the two 2D arrays (xx and yy) into a single 2D array where each row represents a point in the feature space (Visit Duration and Pages Visited). The ravel() function flattens the arrays into 1D.
